# %%
n_bins = 25

# %%
interesting_columns = [
    'costheta_X_reco',
    'costheta_L_reco',
    'chi_reco',
    'q2_reco',
    'isolation_bdt',
    'B0_M',
    'tau_life_reco',
]

# %% [markdown]
# # Compare $B \to D^{*-}\left(D^{+} \to K^+ \pi^+ \pi^+  \right)X$ peak in MC and data
#
# **INPUTS**
# - `MC`: $_s$Weighted $D^+ \to K^+ \pi^+ \pi^-$ peak in MC
# - `data`: $_s$Weighted $D^+ \to K^+ \pi^+ \pi^-$ peak in data
#
# **GOALS**:
# Compare $_s$Weighted `MC` and $_s$Weighted data to see if a reweighting is necessary

# %% [markdown]
# The columns that need to be looked at are:
# - $q^2$: `q2_reco`
# - *isolation BDT*: `isolation_bdt`
# - $m(D^*K\pi\pi)$: `m_DstKpipi`
# - The angles
#     - $cos(\theta_X)$ ($=\theta_D$ in the paper): `costheta_X_reco`
#     - $cos(\theta_L)$: `costheta_L_reco`
#     - $\chi$: `chi_reco`
#
# We'll also look at :
# - $t_\tau$: `tau_life_reco`

# %%
import sys
sys.path.insert(0, '..')
from definition import (
    data_names,
    columns,
    column_ranges,
    colors
)

MC_name   = data_names['MC']
data_name = data_names['data']

print("MC name: ", MC_name)
print("data name: ", data_name)
# Out:
# MC name:  BTODstD0X_MC
# data name:  BTODstD0X

# %%
# python libraries

# bd2dsttaunu
from bd2dsttaunu.locations import loc

# HEA library
from HEA.plot import plot_hist_auto, plot_hist, save_fig, plot_divide_auto
from HEA import load_dataframe
from HEA.plot.tools import draw_vline
from HEA.definition import latex_params
from HEA.pandas_root import load_saved_root
from HEA.tools import get_chi2_2samp
from HEA.tools.string import str_number_into_latex

# %% [markdown]
# ## Read the dataframe

# %%
df = {}
df['MC'] = load_saved_root(MC_name + '_with_sWeights', folder_name=MC_name)
df['data'] = load_saved_root(data_name + '_with_sWeights', folder_name=data_name)
# Out:
# Loading /home/correiaa/bd2dsttaunu/output//root/BTODstD0X_MC/BTODstD0X_MC_with_sWeights.root
# Loading /home/correiaa/bd2dsttaunu/output//root/BTODstD0X/BTODstD0X_with_sWeights.root

# %% [markdown]
# ### Check for NaN values

# %%
# for column in columns:
#     print(column)
#     print('data')
#     print(df['data'][column].isnull().values.any())
#     print('MC')
#     print(df['MC'][column].isnull().values.any())
#     print("")
# Out:
# m_Kpipipi
# data
# False
# MC
# False
#
# q2_reco
# data
# False
# MC
# False
#
# isolation_bdt
# data
# False
# MC
# False
#
# tau_life_reco
# data
# False
# MC
# False
#
# m_DstKpipi
# data
# False
# MC
# False
#
# theta_X_reco
# data
# False
# MC
# False
#
# theta_L_reco
# data
# True
# MC
# True
#
# chi_reco
# data
# False
# MC
# False
#
# costheta_X_reco
# data
# False
# MC
# False
#
# costheta_L_reco
# data
# True
# MC
# True
#
# coschi_reco
# data
# False
# MC
# False
#
# tau_M
# data
# False
# MC
# False
#
# B0_M
# data
# False
# MC
# False

# %% [markdown]
# ### Remove NaN values

# %%
df['data'] = df['data'].dropna()
df['MC'] = df['MC'].dropna()

# %% [markdown]
# ## Plots

# %%
for column in interesting_columns:
    
    chi2 = get_chi2_2samp(data1=df['MC'][column], 
                          data2=df['data'][column], 
                          n_bins=n_bins, 
                          weights1=df['MC']['sWeight'], 
                          weights2=df['data']['sWeight'])
        
    chi2 = str_number_into_latex(f"{chi2:.2g}")
    label = ', $\\chi^2 = {}$'.format(chi2)
    
    
    fig, ax = plot_hist_auto({'MC': df['MC'], 
                              'sWeighted LHCb data':df['data']}, 
                             column, fig_name=column,
                             labels=[label, None],
                             folder_name=f'{MC_name}_vs_{data_name}', 
                             bar_mode=[True, False], 
                             n_bins=n_bins,
                             colors=[colors['MC'], colors['data']], 
                             weights=[df['MC']['sWeight'], df['data']['sWeight']],
                             pos_text_LHC={'ha': 'left', 'fontsize':20})
# Out:
# Figure saved in /home/correiaa/bd2dsttaunu/output/plots//BTODstD0X_MC_vs_BTODstD0X/costheta_X_reco
# Figure saved in /home/correiaa/bd2dsttaunu/output/plots//BTODstD0X_MC_vs_BTODstD0X/costheta_L_reco
# Figure saved in /home/correiaa/bd2dsttaunu/output/plots//BTODstD0X_MC_vs_BTODstD0X/chi_reco
# Figure saved in /home/correiaa/bd2dsttaunu/output/plots//BTODstD0X_MC_vs_BTODstD0X/q2_reco
# Figure saved in /home/correiaa/bd2dsttaunu/output/plots//BTODstD0X_MC_vs_BTODstD0X/isolation_bdt
# Figure saved in /home/correiaa/bd2dsttaunu/output/plots//BTODstD0X_MC_vs_BTODstD0X/B0_M
# Figure saved in /home/correiaa/bd2dsttaunu/output/plots//BTODstD0X_MC_vs_BTODstD0X/tau_life_reco

# %% [markdown]
# Reweighting is needed.
